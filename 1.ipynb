# %%
print(1)
# Out:
# 1

# %%
print(2)

# %%
a = 17
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
# Out:
# 20
# 14
# 51
# 5.666666666666667
# 5
# 2

# %%
a = int(input())
b = int(input())
print(a+b)
# Out:
# 16

# %%
int('10')
# Out:
# 10

# %%
1) Целые числа - integer - int
2) Дробные числа - float 
3) Строки - "10" "Арсений" - string - str
4) Логический - boolean - bool True/False
5) NoneType - None

# %%
import random
def attack(damage, monster_health):
    if damage >= monster_health:
        return 'Монстр побежден'
    elif damage * 2 >= monster_health:
        return 'Монстр ранен'
    else:
        return 'Атака слишком слабая'
monster_health = random.randint(10, 20)
damage = random.randint(1, 20)
